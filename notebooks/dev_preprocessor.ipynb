# %%
import sys
sys.path.append("../src")

from data_loader import load
from preprocessor import preprocess

df = load(source = "synthetic")
X_train, X_val, y_train, y_val = preprocess(df)

print("\nNormalization check (values should be between 0 and 1):")
print("X_train min:", X_train.min().round(4))
print("X_train max:", X_train.max().round(4))
print("X_val   min:", X_val.min().round(4))
print("X_val   max:", X_val.max().round(4))
# Out:
# Loaded synthetic data
# Shape   : (1000, 7)
# Columns : ['battery_voltage', 'solar_current', 'panel_temp', 'onboard_temp', 'attitude_error', 'reaction_wheel_rpm', 'label']
# Faults  : 124
# Nominal : 876
# No low-variance columns found — keeping all features
# X_train : (800, 6)  faults: 99
# X_val   : (200, 6)  faults: 25
#
# Normalization check (values should be between 0 and 1):
# X_train min: 0.0
# X_train max: 1.0
# X_val   min: 0.0007
# X_val   max: 1.0031
